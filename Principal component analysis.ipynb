# %% [markdown]
# [Principal component analysis, (PCA)](https://uk.wikipedia.org/wiki/Метод_головних_компонент) — метод факторного аналізу в статистиці, який використовує ортогональне перетворення множини спостережень з можливо пов'язаними змінними (сутностями, кожна з яких набуває різних числових значень) у множину змінних без лінійної кореляції, які називаються головними компонентами.
#
# Один із основних способів зменшити розмірність даних, втративши найменшу кількість інформації.

# %%
import numpy as np
from pca import pca
import matplotlib.pyplot as plt

# генерируем линейную зависимость оценок
R = np.random.randint(75,120,50)
stat = [elem + np.random.randint(-10,10) for elem in R]
X = np.column_stack((R, stat))

x = X[:,0]
y = X[:,1]

# рисуем диаграмму рассеивания 
plt.figure(figsize=(6, 6))
plt.scatter(x, y)

# добавляем регрессионную прямую
b1, b0 = np.polyfit(x, y, 1) #  b0 - intercept, b1 - slope
plt.plot(x, b0 + b1*x, color='red')
plt.grid()
plt.show()

# %%
# настраиваем модель с 2-мя компонентами
model = pca(n_components=2)
results = model.fit_transform(X)

# столбчатая диаграмма
fig, ax = model.plot()

# диаграмма рассеивания с новыми координатами
fig, ax = model.biplot(n_feat=4)
plt.show()
# Out:
# [pca] >Column labels are auto-completed.
# [pca] >Row labels are auto-completed.
# [pca] >The PCA reduction is performed on the [2] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[2]
# [pca] >Outlier detection using SPE/DmodX with n_std=[2]
# [pca] >Plot PC1 vs PC2 with loadings.

# %%
# import rpy2.ipython
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# dt <- swiss
# dt$is_catholic <- ifelse(swiss$Catholic > 50, 1, 0)
# dt$is_catholic <- factor(dt$is_catholic)
# fit <- prcomp(swiss, center = T)
# pca3d::pca3d(fit, group = dt$is_catholic,
#       fancy = T, 
#       new=T)

# %%
# from rpy2.robjects.packages import importr, data
# utils = importr('utils')
# base = importr('base')
# utils.install_packages('pca3d')
# pca3d = importr('pca3d')

# # %%R
# # library(pca3d)

# %% [markdown]
# #
#
# Щоб краще розібратися в PCA, можна прочитати матеріал за цими трьома посиланнями:
#
# 1. Спочатку загальна концепція https://blog.bioturing.com/2018/06/14/principal-component-analysis-explained-simply/
#
# 2. Потім більш поглиблено з прикладами з R http://www.sthda.com/english/articles/31-principal-component-methods-in-r-practical-guide/112-pca-principal-component-analysis-essentials /
#
# 3. Трохи про інтерпретацію графіків: https://blog.bioturing.com/2018/06/18/how-to-read-pca-biplots-and-scree-plots/

# %%
import rpy2.ipython
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
#https://rpy2.github.io/doc/latest/html/introduction.html

# from rpy2.robjects.packages import importr, data
# utils = importr('utils')
# utils.install_packages('FactoMineR')
import rpy2.robjects.packages as rpackages

# import R's utility package
utils = rpackages.importr('utils')
# select a mirror for R packages
utils.chooseCRANmirror(ind=1) # select the first mirror in the list
utils.install_packages('FactoMineR')
# Скачанные бинарные пакеты находятся в
# 	C:\Users\GbreH\AppData\Local\Temp\RtmpSKdkJI\downloaded_packages
# Out:
# R[write to console]: устанавливаю также зависимости 'broom', 'numDeriv', 'SparseM', 'MatrixModels', 'sp', 'minqa', 'nloptr', 'RcppEigen', 'lazyeval', 'later', 'carData', 'abind', 'pbkrtest', 'quantreg', 'maptools', 'lme4', 'crosstalk', 'jquerylib', 'promises', 'car', 'DT', 'ellipse', 'flashClust', 'leaps', 'scatterplot3d'
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/bin/windows/contrib/4.2/broom_1.0.0.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 1861401 bytes (1.8 MB)
#
# R[write to console]: downloaded 1.8 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/bin/windows/contrib/4.2/numDeriv_2016.8-1.1.zip'
#
# R[write to console]: Content type 'application/zip'
# R[write to console]:  length 116102 bytes (113 KB)
#
# R[write to console]: downloaded 113 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/bin/windows/contrib/4.2/SparseM_1.81.zip'
#
# ...

# %%
# %%R
# # library(FactoMineR)
# df <- mtcars[,c(1,3:7)]
# res.pca <- FactoMineR::PCA(df, graph=TRUE)
